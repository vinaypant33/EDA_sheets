# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows' , 1000)
pd.set_option('display.max_columns' , 1000)

# %%
df = pd.read_csv('ev_data.csv')

# %% [markdown]
# Steps for the analysis ::
#
# 1. Check for the basic parameters :: info describe and head etc
# 2. Check for the null values in the rows and columns and if yes do the impudence / fill with constants and delete the rows and columns
# 3. Make the graphs for the univariate and Bivariate analysis and make the graphs for the univariate and bivariate analysis
# 4. make the conclusion for the data done

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12654 entries, 0 to 12653
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      12654 non-null  object
#  1   category    12654 non-null  object
#  2   parameter   12654 non-null  object
#  3   mode        12654 non-null  object
#  4   powertrain  12654 non-null  object
#  5   year        12654 non-null  int64
#  6   unit        12654 non-null  object
#  7   value       12654 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 791.0+ KB

# %%
df.describe()
# Out:
#                year         value
# count  12654.000000  1.265400e+04
# mean    2019.822112  4.273742e+05
# std        5.476494  6.860498e+06
# min     2010.000000  1.200000e-06
# 25%     2016.000000  2.000000e+00
# 50%     2020.000000  1.300000e+02
# 75%     2022.000000  5.500000e+03
# max     2035.000000  4.400000e+08

# %%
df.head(10)
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
# 5  Australia  Historical        EV sales  Cars        BEV  2012  Vehicles
# 6  Australia  Historical  EV sales share  Cars         EV  2012   percent
# 7  Australia  Historical  EV stock share  Cars         EV  2012   percent
# 8  Australia  Historical        EV stock  Cars       PHEV  2012  Vehicles
# 9  Australia  Historical        EV sales  Cars       PHEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000
# 5  170.00000
# 6    0.03000
# 7    0.00240
# 8   80.00000
# ...

# %%
df.isnull().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
# No null values in the data frame so no need to make the impudence / Constants. Nor we have to delete the data values  :

# Do univaraite and Multivariate analysis using the grpahs  : 
df.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000

# %%
plt.bar(df['region'] , df['value'])
# Out:
# <BarContainer object of 12654 artists>

# %%
sns.barplot(df['region'])
# Out:
# <Axes: ylabel='region'>

# %%
sns.displot(df['region'] , bins = 10 , color='g')
